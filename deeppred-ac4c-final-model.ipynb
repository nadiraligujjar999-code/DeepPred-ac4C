# %% [markdown]
# # ac4C Pipeline (Keras/TensorFlow)
# This notebook is a single combined pipeline for ac4C prediction.
#
# ## What is included
# - Loads labeled FASTA train/test files
# - PSTNP options (position-specific trinucleotide propensity):
#   - `pstnp_mode="ss"`  → PSTNPss
#   - `pstnp_mode="ds"`  → PSTNPds
#   - `pstnp_mode="both"`→ concatenation of ss + ds
# - Hybrid model:
#   - onehot + k-mer frequency features + CNN encoder + Transformer encoder
#   - fusion with handcrafted vector features
#
# > Paths expected:
# - `/mnt/data/trainset_labeled.txt`
# - `/mnt/data/testset_labeled.txt`

# %%
# Cell 0 — run BEFORE importing tensorflow anywhere
# !pip -q install "protobuf<6"

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
os.environ["PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION"] = "python"

print("Done. Now restart the session: Runtime → Restart session")
# Out:
# Done. Now restart the session: Runtime → Restart session

# %%
# ========= 0) Imports & Global Config =========
import os, re
import numpy as np
import tensorflow as tf
from itertools import product
from sklearn.metrics import confusion_matrix, roc_auc_score, average_precision_score

print("TensorFlow:", tf.__version__)
# Out:
# 2026-06-23 06:41:10.806627: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1782196871.001173      57 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1782196871.063204      57 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1782196871.533749      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782196871.533801      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782196871.533804      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1782196871.533806      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# TensorFlow: 2.19.0

# %% [markdown]
# ### Configurations

# %%
# Reproducibility
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Data paths (EDIT if needed)
TRAIN_PATH = r"/kaggle/input/datasets/nadiralii/ac4c-dataset-correct/trainset_labeled.txt"
TEST_PATH  = r"/kaggle/input/datasets/nadiralii/ac4c-dataset-correct/testset_labeled.fasta"
DINUC_PROP_PATH = r"/kaggle/input/datasets/nadiralii/ac4c-dataset-correct/diRNAPhyche.txt"
# Sequence length
L = 201

# -------- Handcrafted controls --------
# PSTNP mode: "ss", "ds", "both"
PSTNP_MODE = "ds" # "both"


# -------- Training controls --------
BATCH_SIZE = 32
EPOCHS_TRAIN = 200

# Model settings
D_MODEL = 128
D_FF = 256
NUM_HEADS = 4
NUM_LAYERS = 2
CNN_FILTERS = (7, 7)
CNN_KERNELS = (3,3)
CNN_DROPOUT = 0.15
TRANSFORMER_DROPOUT = 0.1

# Checkpoint for optional pretraining
OUT_DIR = "outputs"
os.makedirs(OUT_DIR, exist_ok=True)
ENCODER_CKPT = os.path.join(OUT_DIR, "pretrained_encoder.weights.h5")

# %% [markdown]
# ## 1) Data Loader (FASTA labeled)

# %%
def read_fasta_labeled(path: str, convert_t_to_u: bool = True):
    """Reads FASTA-like labeled format where the last header token is 0/1 (or label=0/1)."""
    ids, seqs, labels = [], [], []
    cur_id, cur_label, cur_seq = None, None, []

    def flush():
        nonlocal cur_id, cur_label, cur_seq
        if cur_id is not None:
            s = "".join(cur_seq).strip().upper()
            if convert_t_to_u:
                s = s.replace("T", "U")
            ids.append(cur_id)
            seqs.append(s)
            labels.append(int(cur_label))
        cur_id, cur_label, cur_seq = None, None, []

    with open(path, "r", encoding="utf-8") as f:
        for raw in f:
            line = raw.strip()
            if not line:
                continue
            if line.startswith(">"):
                flush()
                header = line[1:]
                m = re.search(r"(?:label=)?([01])\s*$", header)
                if not m:
                    raise ValueError(f"Cannot parse label from header: {line}")
                cur_label = int(m.group(1))
                cur_id = header[: m.start()].strip()
            else:
                cur_seq.append(line)

    flush()
    return ids, seqs, np.array(labels, dtype=np.int64)

def validate_fixed_length(seqs, L_expected=201):
    bad = [(i, len(s)) for i, s in enumerate(seqs) if len(s) != L_expected]
    if bad:
        raise ValueError(f"Found {len(bad)} sequences not length={L_expected}. Example: {bad[:5]}")

tr_ids, tr_seqs, y_train = read_fasta_labeled(TRAIN_PATH)
te_ids, te_seqs, y_test  = read_fasta_labeled(TEST_PATH)
validate_fixed_length(tr_seqs, L)
validate_fixed_length(te_seqs, L)

print("Train:", len(tr_seqs), "Pos:", int(y_train.sum()), "Neg:", int((y_train==0).sum()))
print("Test :", len(te_seqs), "Pos:", int(y_test.sum()), "Neg:", int((y_test==0).sum()))
print("Example id:", tr_ids[0])
print("Example seq:", tr_seqs[0][:30]+"...")
# Out:
# Train: 4412 Pos: 2206 Neg: 2206
# Test : 1104 Pos: 552 Neg: 552
# Example id: uc002yel.3_915_1734_1171
# Example seq: AGAACAGCGGUCUGGACCACUUCCAAAACA...

# %% [markdown]
# ## 2) Load diRNAPhyche.txt (robust) + property selection

# %%
NUC_RNA = "ACGU"
NUC_DNA = "ACGT"

def load_dinuc_properties_matrix(path: str):
    """
    Robust loader for iLearnPlus-like dinucleotide property files.
    Returns:
      prop_names: list[str] (P)
      dinuc_order: list[str] (16)
      M: np.ndarray shape (P, 16)
    """
    with open(path, "r", encoding="utf-8") as f:
        raw = [ln.rstrip("\n") for ln in f if ln.strip()]

    header = raw[0].strip()
    hparts = header.split("\t") if "\t" in header else header.split()
    if len(hparts) < 17:
        raise ValueError(f"Unexpected header: {header}")

    dinuc_order = [x.upper().replace("T", "U") for x in hparts[-16:]]  # normalize header to RNA-style tokens

    prop_names, rows = [], []
    for ln in raw[1:]:
        parts = ln.split("\t") if "\t" in ln else ln.split()
        if len(parts) < 17:
            raise ValueError(f"Bad row: {ln}")
        last16 = parts[-16:]
        vals = [float(x) for x in last16]
        pname = " ".join(parts[:-16]).strip()
        prop_names.append(pname)
        rows.append(vals)

    M = np.array(rows, dtype=np.float64)  # (P,16)
    return prop_names, dinuc_order, M

def select_properties(prop_names, selected="all"):
    """
    selected:
      - 'all'
      - list of exact names
      - list of keywords (partial match, case-insensitive)
    Returns: list of indices
    """
    if selected is None or selected == "all":
        return list(range(len(prop_names)))
    if isinstance(selected, str):
        selected = [selected]

    out = []
    for s in selected:
        s2 = s.lower()
        hits = [i for i, pn in enumerate(prop_names) if (pn.lower() == s2 or s2 in pn.lower())]
        if not hits:
            raise ValueError(f"Property '{s}' not found (even as partial match).")
        for i in hits:
            if i not in out:
                out.append(i)
    return out

def zscore_rows(M: np.ndarray) -> np.ndarray:
    mu = M.mean(axis=1, keepdims=True)
    sd = M.std(axis=1, keepdims=True)
    sd[sd == 0] = 1.0
    return (M - mu) / sd

prop_names, dinuc_order, M_prop = load_dinuc_properties_matrix(DINUC_PROP_PATH)
prop_idx = select_properties(prop_names)
M_sel = M_prop[prop_idx, :]  

print("Total properties:", len(prop_names))
print("Selected properties:", len(prop_idx))
print("Example selected names:", [prop_names[i] for i in prop_idx[:5]])
print("Dinuc order (from file, normalized to RNA):", dinuc_order)
# Out:
# Total properties: 22
# Selected properties: 22
# Example selected names: ['Slide (RNA)', 'Adenine content', 'Hydrophilicity (RNA)', 'Tilt (RNA)', 'Stacking energy (RNA)']
# Dinuc order (from file, normalized to RNA): ['AA', 'AC', 'AG', 'AU', 'CA', 'CC', 'CG', 'CU', 'GA', 'GC', 'GG', 'GU', 'UA', 'UC', 'UG', 'UU']

# %% [markdown]
# ## 3) PSTNP (ss/ds/both) — fit on TRAIN only (no leave-one-out)

# %%
def all_kmers(k: int, alphabet: str):
    return ["".join(p) for p in product(alphabet, repeat=k)]

class PSTNPComputer:
    """
    PSTNPss/PSTNPds positional encoding.

    - Fits ONLY on training split (train_seqs + y_train)
    - No leave-one-out (because train/test are already separated)
    - transform() uses learned delta tables

    mode:
      ss   -> full RNA alphabet A/C/G/U (64 tri)
      ds   -> degenerate mapping: U->A and G->C; alphabet A/C (8 tri)
      both -> concat [ss, ds]
    """
    def __init__(self, L: int, mode: str = "ss", eps: float = 0.0):
        assert mode in {"ss", "ds", "both"}
        self.L = L
        self.mode = mode
        self.eps = eps
        self._fitted = False

    def _fit_one(self, train_seqs, y_train, alphabet: str, map_fn=None):
        k = 3
        positions = self.L - k + 1
        kmers = all_kmers(k, alphabet)
        kmer_index = {m: i for i, m in enumerate(kmers)}
        V = len(kmers)

        y_train = np.asarray(y_train).astype(int)
        Npos = int((y_train == 1).sum())
        Nneg = int((y_train == 0).sum())
        if Npos == 0 or Nneg == 0:
            raise ValueError("PSTNP fit requires both classes in training split.")

        cpos = np.zeros((positions, V), dtype=np.float64)
        cneg = np.zeros((positions, V), dtype=np.float64)

        for s, lab in zip(train_seqs, y_train):
            s = s.upper().replace("T", "U")
            if map_fn is not None:
                s = map_fn(s)
            for p in range(positions):
                tri = s[p:p+3]
                j = kmer_index.get(tri)
                if j is None:
                    continue
                if lab == 1:
                    cpos[p, j] += 1.0
                else:
                    cneg[p, j] += 1.0

        fpos = (cpos + self.eps) / (Npos + self.eps * V)
        fneg = (cneg + self.eps) / (Nneg + self.eps * V)
        delta = fpos - fneg
        return delta, kmer_index

    def fit(self, train_seqs, y_train):
        # ss tables
        self.delta_ss, self.index_ss = self._fit_one(train_seqs, y_train, alphabet="ACGU", map_fn=None)

        # ds tables: U->A, G->C (RNA equivalent of FileProcessing T->A, G->C)
        def map_ds(s: str) -> str:
            return s.replace("U", "A").replace("G", "C")
        self.delta_ds, self.index_ds = self._fit_one(train_seqs, y_train, alphabet="AC", map_fn=map_ds)

        self._fitted = True
        return self

    def _transform_one(self, seqs, delta, kmer_index, map_fn=None):
        k = 3
        positions = self.L - k + 1
        X = np.zeros((len(seqs), positions), dtype=np.float32)
        for i, s in enumerate(seqs):
            s = s.upper().replace("T", "U")
            if map_fn is not None:
                s = map_fn(s)
            for p in range(positions):
                tri = s[p:p+3]
                j = kmer_index.get(tri)
                X[i, p] = float(delta[p, j]) if j is not None else 0.0
        return X

    def transform(self, seqs):
        if not self._fitted:
            raise RuntimeError("Call fit() before transform().")

        if self.mode == "ss":
            return self._transform_one(seqs, self.delta_ss, self.index_ss, map_fn=None)

        if self.mode == "ds":
            def map_ds(s: str) -> str:
                return s.replace("U", "A").replace("G", "C")
            return self._transform_one(seqs, self.delta_ds, self.index_ds, map_fn=map_ds)

        # both
        def map_ds(s: str) -> str:
            return s.replace("U", "A").replace("G", "C")
        Xss = self._transform_one(seqs, self.delta_ss, self.index_ss, map_fn=None)
        Xds = self._transform_one(seqs, self.delta_ds, self.index_ds, map_fn=map_ds)
        return np.concatenate([Xss, Xds], axis=1)

# -------- Handcrafted controls --------
# PSTNP mode: "ss", "ds", "both"
PSTNP_MODE = "ds"

pst = PSTNPComputer(L=L, mode=PSTNP_MODE).fit(tr_seqs, y_train)
Xtr_pst = pst.transform(tr_seqs)
Xte_pst = pst.transform(te_seqs)
print("PSTNP mode:", PSTNP_MODE)
print("PSTNP shapes:", Xtr_pst.shape, Xte_pst.shape)
# Out:
# PSTNP mode: ds
# PSTNP shapes: (4412, 199) (1104, 199)

# %% [markdown]
# ## 5) Final handcrafted vector

# %%
Xtr_hand = Xtr_pst.astype(np.float32)
Xte_hand = Xte_pst.astype(np.float32)
D_HAND = Xtr_hand.shape[1]

print("Handcrafted shapes:", Xtr_hand.shape, Xte_hand.shape)
print("d_hand =", D_HAND)
# Out:
# Handcrafted shapes: (4412, 199) (1104, 199)
# d_hand = 199

# %% [markdown]
# ## 6) Sequence encodings (onehot + k-mer ids)

# %%
# ============================================================
# Correct feature construction
# onehot remains positional: (N, L, 4)
# k-mer features are now composition/frequency vectors:
#   k=1 -> 4, k=2 -> 16, k=3 -> 64
# ============================================================
NUC_RNA = "ACGU"
NUC2ID = {"A": 0, "C": 1, "G": 2, "U": 3, "T": 3}

def onehot_encode(seq: str, L: int) -> np.ndarray:
    seq = seq.upper().replace("T", "U")
    x = np.zeros((L, 4), dtype=np.float32)
    for i, ch in enumerate(seq[:L]):
        if ch in NUC2ID:
            x[i, NUC2ID[ch]] = 1.0
    return x

def kmer_vocab(k: int, alphabet: str = NUC_RNA):
    return ["".join(p) for p in product(alphabet, repeat=k)]

def kmer_freq_vector(seq: str, k: int, alphabet: str = NUC_RNA) -> np.ndarray:
    """
    Returns normalized k-mer composition vector of length 4^k.
    For fixed RNA alphabet A/C/G/U:
      k=1 -> 4 columns
      k=2 -> 16 columns
      k=3 -> 64 columns
    """
    seq = seq.upper().replace("T", "U")
    vocab = kmer_vocab(k, alphabet)
    idx = {m: i for i, m in enumerate(vocab)}
    x = np.zeros(len(vocab), dtype=np.float32)

    valid_windows = 0
    for i in range(0, len(seq) - k + 1):
        mer = seq[i:i+k]
        if all(ch in alphabet for ch in mer):
            x[idx[mer]] += 1.0
            valid_windows += 1

    if valid_windows > 0:
        x /= float(valid_windows)
    return x

def make_base_inputs(seqs: list[str], L: int):
    n = len(seqs)
    x_onehot = np.zeros((n, L, 4), dtype=np.float32)
    x_k1 = np.zeros((n, 4**1), dtype=np.float32)
    x_k2 = np.zeros((n, 4**2), dtype=np.float32)
    x_k3 = np.zeros((n, 4**3), dtype=np.float32)

    for i, s in enumerate(seqs):
        s = s[:L]
        x_onehot[i] = onehot_encode(s, L)
        x_k1[i] = kmer_freq_vector(s, 1)
        x_k2[i] = kmer_freq_vector(s, 2)
        x_k3[i] = kmer_freq_vector(s, 3)

    return x_onehot, x_k1, x_k2, x_k3

Xtr_onehot, Xtr_k1, Xtr_k2, Xtr_k3 = make_base_inputs(tr_seqs, L)
Xte_onehot, Xte_k1, Xte_k2, Xte_k3 = make_base_inputs(te_seqs, L)

print("onehot:", Xtr_onehot.shape, "k1:", Xtr_k1.shape, "k2:", Xtr_k2.shape, "k3:", Xtr_k3.shape)
# Out:
# onehot: (4412, 201, 4) k1: (4412, 4) k2: (4412, 16) k3: (4412, 64)

# %% [markdown]
# ### 7 Feature nomalization and reduction using PCA/SVD

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA, TruncatedSVD

scaler = MinMaxScaler()
# scaler = StandardScaler()
Xtr_hand = scaler.fit_transform(Xtr_hand)
Xte_hand = scaler.transform(Xte_hand)

# svd = TruncatedSVD(n_components=0.95, random_state=SEED)
# pca = PCA(n_components=200, random_state=SEED)
# Xtr_hand = pca.fit_transform(Xtr_hand)
# Xte_hand = pca.transform(Xte_hand)

# Xtr_hand = Xtr_hand.astype(np.float32)
# Xte_hand = Xte_hand.astype(np.float32)

print("After PCA:", Xtr_hand.shape, Xte_hand.shape)

# IMPORTANT: update D_HAND after PCA
D_HAND = Xtr_hand.shape[1]
print("New d_hand =", D_HAND)
# Out:
# After PCA: (4412, 199) (1104, 199)
# New d_hand = 199

# %%
# IMPORTANT: update D_HAND after PCA
D_HAND = Xtr_hand.shape[1] # (285,1) #
print("New d_hand =", D_HAND)
# Out:
# New d_hand = 225

# %% [markdown]
# ## 8) tf.data datasets

# %%
def make_tf_dataset(inputs: dict, y: np.ndarray, batch_size: int, training: bool):
    ds = tf.data.Dataset.from_tensor_slices((inputs, y.astype(np.float32)))
    if training:
        ds = ds.shuffle(min(len(y), 10000), reshuffle_each_iteration=True)
    ds = ds.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return ds


Xtr_hand = np.array(Xtr_hand).reshape(-1,Xtr_hand.shape[1],1)
Xte_hand = np.array(Xte_hand).reshape(-1,Xtr_hand.shape[1],1)
train_inputs = {"onehot": Xtr_onehot, "k1": Xtr_k1, "k2": Xtr_k2, "k3": Xtr_k3, "hand": Xtr_hand}
test_inputs  = {"onehot": Xte_onehot, "k1": Xte_k1, "k2": Xte_k2, "k3": Xte_k3, "hand": Xte_hand}

ds_tr = make_tf_dataset(train_inputs, y_train, BATCH_SIZE, training=True)
ds_te = make_tf_dataset(test_inputs,  y_test,  BATCH_SIZE, training=False)

batch = next(iter(ds_tr))
print("Batch onehot:", batch[0]["onehot"].shape, "Batch hand:", batch[0]["hand"].shape)
# Out:
# I0000 00:00:1777511184.645014      22 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Batch onehot: (32, 201, 4) Batch hand: (32, 225, 1)

# %%
# ============================================================
# ABLATION STUDY 
# Flexible model + helpers for independent-test evaluation
# k1/k2/k3 are vector features with dims 4/16/64.
# onehot remains sequence input with shape (L, 4).
# ============================================================

import numpy as np
import pandas as pd
import tensorflow as tf

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, roc_auc_score, average_precision_score

class PrintOnlyImprovements(tf.keras.callbacks.Callback):
    def __init__(self):
        super().__init__()
        self.best_val_acc = 0.0
        self.best_val_loss = float('inf')

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        val_acc = logs.get('val_accuracy') or logs.get('val_acc')
        val_loss = logs.get('val_loss')
        improved = []
        if val_loss is not None and val_loss < self.best_val_loss:
            self.best_val_loss = val_loss
            improved.append(f"Loss: {val_loss:.4f}")
        if val_acc is not None and val_acc > self.best_val_acc:
            self.best_val_acc = val_acc
            improved.append(f"Acc: {val_acc:.4f}")
        if improved:
            print(f"Epoch {epoch+1}: {' | '.join(improved)}")

np.random.seed(SEED)
tf.random.set_seed(SEED)

# -----------------------------
# Safety: correct dtypes
# -----------------------------
Xtr_onehot = np.asarray(Xtr_onehot, dtype=np.float32)
Xte_onehot = np.asarray(Xte_onehot, dtype=np.float32)

# k-mer frequency vectors, not integer token sequences
Xtr_k1 = np.asarray(Xtr_k1, dtype=np.float32)
Xte_k1 = np.asarray(Xte_k1, dtype=np.float32)
Xtr_k2 = np.asarray(Xtr_k2, dtype=np.float32)
Xte_k2 = np.asarray(Xte_k2, dtype=np.float32)
Xtr_k3 = np.asarray(Xtr_k3, dtype=np.float32)
Xte_k3 = np.asarray(Xte_k3, dtype=np.float32)

Xtr_pst = np.asarray(Xtr_pst, dtype=np.float32)
Xte_pst = np.asarray(Xte_pst, dtype=np.float32)

y_train = np.asarray(y_train).astype(np.float32)
y_test  = np.asarray(y_test).astype(np.float32)

print("Data shapes:")
print("onehot:", Xtr_onehot.shape, Xte_onehot.shape)
print("k1    :", Xtr_k1.shape, Xte_k1.shape, "expected dim=4")
print("k2    :", Xtr_k2.shape, Xte_k2.shape, "expected dim=16")
print("k3    :", Xtr_k3.shape, Xte_k3.shape, "expected dim=64")
print("pstnp :", Xtr_pst.shape, Xte_pst.shape)


def compute_binary_metrics(y_true, y_prob, thr=0.5):
    y_true = np.asarray(y_true).astype(int)
    y_prob = np.asarray(y_prob).astype(float).ravel()
    y_pred = (y_prob >= thr).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred, labels=[0, 1]).ravel()
    acc = (tp + tn) / max(tp + tn + fp + fn, 1)
    sn = tp / max(tp + fn, 1)
    sp = tn / max(tn + fp, 1)
    denom = np.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))
    mcc = ((tp * tn) - (fp * fn)) / denom if denom > 0 else 0.0
    roc = roc_auc_score(y_true, y_prob) if len(np.unique(y_true)) == 2 else float("nan")
    ap  = average_precision_score(y_true, y_prob) if len(np.unique(y_true)) == 2 else float("nan")
    return {"ACC": acc, "SN": sn, "SP": sp, "MCC": mcc, "ROC_AUC": roc, "PR_AUC": ap}


def build_cnn_encoder(d_model=32, filters=32, kernel_size=3, dropout=0.15, name="cnn_encoder_downstream"):
    inp = tf.keras.Input(shape=(None, d_model), name=f"{name}_in")
    x = tf.keras.layers.Conv1D(filters, kernel_size, padding="same", activation="relu",
                               kernel_regularizer=tf.keras.regularizers.l2(0.0001))(inp)
    x = tf.keras.layers.AveragePooling1D(2)(x)
    x = tf.keras.layers.Dropout(dropout)(x)
    x = tf.keras.layers.Dense(d_model)(x)
    return tf.keras.Model(inp, x, name=name)

class PositionalEmbedding(tf.keras.layers.Layer):
    def __init__(self, max_len: int, d_model: int, **kwargs):
        super().__init__(**kwargs)
        self.pos_emb = tf.keras.layers.Embedding(input_dim=max_len, output_dim=d_model)
    def call(self, x):
        T = tf.shape(x)[1]
        positions = tf.range(start=0, limit=T, delta=1)
        return x + self.pos_emb(positions)

class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, d_model: int, num_heads: int, d_ff: int, dropout: float = 0.1, **kwargs):
        super().__init__(**kwargs)
        self.mha = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=d_model // num_heads, dropout=dropout)
        self.ffn = tf.keras.Sequential([
            tf.keras.layers.Dense(d_ff, activation="relu"),
            tf.keras.layers.Dropout(dropout),
            tf.keras.layers.Dense(d_model),
        ])
        self.ln1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.ln2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.do1 = tf.keras.layers.Dropout(dropout)
        self.do2 = tf.keras.layers.Dropout(dropout)
    def call(self, x, training=True):
        attn_out = self.mha(x, x, training=training)
        x = self.ln1(x + self.do1(attn_out, training=training))
        ffn_out = self.ffn(x, training=training)
        x = self.ln2(x + self.do2(ffn_out, training=training))
        return x


def prepare_ablation_inputs(feature_names):
    """
    Allowed feature_names:
      onehot, k1, k2, k3, pstnp

    onehot is treated as positional sequence input.
    k1/k2/k3/pstnp are concatenated as selected vector features.
    """
    feature_names = tuple(feature_names)
    Xtr_dict, Xte_dict = {}, {}

    if "onehot" in feature_names:
        Xtr_dict["onehot"] = Xtr_onehot
        Xte_dict["onehot"] = Xte_onehot

    vec_parts_tr, vec_parts_te = [], []
    vector_bank = {
        "k1": (Xtr_k1, Xte_k1),
        "k2": (Xtr_k2, Xte_k2),
        "k3": (Xtr_k3, Xte_k3),
        "pstnp": (Xtr_pst, Xte_pst),
    }

    for name in ["k1", "k2", "k3", "pstnp"]:
        if name in feature_names:
            a_tr, a_te = vector_bank[name]
            vec_parts_tr.append(a_tr)
            vec_parts_te.append(a_te)

    vector_dim = 0
    if vec_parts_tr:
        Xtr_vec = np.concatenate(vec_parts_tr, axis=1).astype(np.float32)
        Xte_vec = np.concatenate(vec_parts_te, axis=1).astype(np.float32)

        scaler = MinMaxScaler()
        Xtr_vec = scaler.fit_transform(Xtr_vec).astype(np.float32)
        Xte_vec = scaler.transform(Xte_vec).astype(np.float32)

        vector_dim = Xtr_vec.shape[1]
        Xtr_dict["hand"] = Xtr_vec.reshape(-1, vector_dim, 1)
        Xte_dict["hand"] = Xte_vec.reshape(-1, vector_dim, 1)

    return Xtr_dict, Xte_dict, vector_dim


def build_final_classifier(feature_names, vector_dim):
    feature_names = tuple(feature_names)
    inputs = {}
    branches = []

    # onehot positional branch
    if "onehot" in feature_names:
        inp_onehot = tf.keras.Input(shape=(L, 4), name="onehot")
        x = tf.keras.layers.Dense(32, activation="relu", name="seq_project")(inp_onehot)
        cnn_encoder = build_cnn_encoder(d_model=32, filters=7, kernel_size=3, dropout=0.15,
                                        name="cnn_encoder_downstream")
        x = cnn_encoder(x)
        x = tf.keras.layers.Bidirectional(
            tf.keras.layers.LSTM(16, return_sequences=True, dropout=0.2,
                                 recurrent_dropout=0.0, activation="relu")
        )(x)
        x = PositionalEmbedding(max_len=L, d_model=32, name="pos_emb")(x)
        x = TransformerBlock(d_model=32, num_heads=8, d_ff=32, dropout=0.4, name="tr_block_1")(x)
        x = tf.keras.layers.AveragePooling1D(4)(x)
        x = tf.keras.layers.Dropout(0.2)(x)
        x = tf.keras.layers.Flatten()(x)
        inputs["onehot"] = inp_onehot
        branches.append(x)

    # selected vector-feature branch: kmer frequency + PSTNP
    if vector_dim > 0:
        inp_vec = tf.keras.Input(shape=(vector_dim, 1), name="hand")
        # x = tf.keras.layers.Conv1D(8, 3, padding="same", activation="relu",
        #                            kernel_regularizer=tf.keras.regularizers.l2(0.0001))(inp_vec)
        cnn_encoder1 = build_cnn_encoder(d_model=32, filters=7, kernel_size=3, dropout=0.15,
                                        name="cnn_encoder_downstream")
        x = cnn_encoder1(inp_vec)
        x = tf.keras.layers.AveragePooling1D(2)(x)
        x = tf.keras.layers.Dropout(0.3)(x)
        x = tf.keras.layers.Flatten()(x)
        inputs["hand"] = inp_vec
        branches.append(x)

    if not branches:
        raise ValueError("At least one feature must be selected.")
    z = branches[0] if len(branches) == 1 else tf.keras.layers.Concatenate(name="final_fusion")(branches)
    z = tf.keras.layers.Dropout(0.4)(z)
    out = tf.keras.layers.Dense(1, activation="sigmoid")(z)
    return tf.keras.Model(inputs=inputs, outputs=out, name="ac4c_ablation_classifier")


def run_final_experiment(exp_name, feature_names, epochs=100, batch_size=32, lr=0.0005, verbose=1):
    tf.keras.backend.clear_session()
    np.random.seed(SEED)
    tf.random.set_seed(SEED)

    Xtr_dict, Xte_dict, vector_dim = prepare_ablation_inputs(feature_names)
    print(f"Selected features: {feature_names}; vector_dim={vector_dim}")

    model = build_final_classifier(feature_names=feature_names, vector_dim=vector_dim)
    model.summary()

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss=tf.keras.losses.BinaryCrossentropy(),
        metrics=["accuracy"]
    )

    callbacks = [
        PrintOnlyImprovements(),
        tf.keras.callbacks.EarlyStopping(monitor="val_accuracy", mode="max", patience=100, restore_best_weights=True),
    ]

    history = model.fit(
        Xtr_dict,
        y_train,
        validation_data=(Xte_dict, y_test),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=callbacks,
        verbose=verbose,
        shuffle=True
    )

    yprob = model.predict(Xte_dict, verbose=0).ravel()
    metrics = compute_binary_metrics(y_test, yprob, thr=0.5)
    row = {"Experiment": exp_name, "Features": "+".join(feature_names), **metrics}
    return row, history, model

print("Corrected ablation block loaded successfully.")
# Out:
# Data shapes:
# onehot: (4412, 201, 4) (1104, 201, 4)
# k1    : (4412, 4) (1104, 4) expected dim=4
# k2    : (4412, 16) (1104, 16) expected dim=16
# k3    : (4412, 64) (1104, 64) expected dim=64
# pstnp : (4412, 199) (1104, 199)
# Corrected ablation block loaded successfully.

# %%
# ------------------------------------------------------------
# Requested experiments
# Duplicate repeated experiments removed automatically
# ------------------------------------------------------------
experiment_list = [
    ("onehot", ("onehot",)),
    ("k1", ("k1",)),
    ("k2", ("k2",)),
    ("k3", ("k3",)),
    ("pstnp", ("pstnp",)),

    ("onehot+k1", ("onehot", "k1")),
    ("onehot+k1+k2", ("onehot", "k1", "k2")),
    ("onehot+k1+pstnp", ("onehot", "k1", "pstnp")),
    ("onehot+pstnp", ("onehot", "pstnp")),
    ("onehot+k1+k2+k3", ("onehot", "k1", "k2", "k3")),
    ("onehot+k1+k2+pstnp", ("onehot", "k1", "k2", "pstnp")),
    ("k1+k2+k3+pstnp", ("k1", "k2", "k3", "pstnp")),
    ("k1+k2+pstnp", ("k1", "k2", "pstnp")),
    ("k1+k2+k3", ("k1", "k2", "k3")),
]

# Remove exact duplicates while keeping order
seen = set()
unique_experiments = []
for name, feats in experiment_list:
    key = tuple(feats)
    if key not in seen:
        unique_experiments.append((name, feats))
        seen.add(key)

print("Experiments to run:")
for i, (name, feats) in enumerate(unique_experiments, 1):
    print(f"{i:02d}. {name:35s} -> {feats}")


# ------------------------------------------------------------
# Run all experiments
# ------------------------------------------------------------
ablation_rows = []
ablation_histories = {}
ablation_models = {}

for idx, (exp_name, feature_names) in enumerate(unique_experiments, 1):
    print("\n" + "=" * 100)
    print(f"Running {idx}/{len(unique_experiments)}: {exp_name}")
    print("=" * 100)

    row, history, model = run_final_experiment(
        exp_name=exp_name,
        feature_names=feature_names,
        epochs=EPOCHS_TRAIN,      # same training setting as your notebook
        batch_size=BATCH_SIZE,    # same batch size as your notebook
        lr=0.0005,                # same learning rate as your notebook
        verbose=0
    )

    ablation_rows.append(row)
    ablation_histories[exp_name] = history.history
    ablation_models[exp_name] = model

    print("Completed:", exp_name)
    print(row)


# ------------------------------------------------------------
# Final result table
# ------------------------------------------------------------
ablation_results_df = pd.DataFrame(ablation_rows)

metric_cols = ["ACC", "SN", "SP", "MCC", "ROC_AUC", "PR_AUC"]
for col in metric_cols:
    ablation_results_df[col] = ablation_results_df[col].astype(float).round(4)

# Journal-style sorting
ablation_results_df = ablation_results_df.sort_values(
    by=["ROC_AUC", "PR_AUC", "ACC", "MCC"],
    ascending=False
).reset_index(drop=True)

print("\nFinal Ablation Results Table:")
display(ablation_results_df)

# Optional save
ablation_results_df.to_csv("ablation_independent_results.csv", index=False)
print("Saved file: ablation_independent_results.csv")
# Out:
# Experiments to run:
# 01. onehot                              -> ('onehot',)
# 02. k1                                  -> ('k1',)
# 03. k2                                  -> ('k2',)
# 04. k3                                  -> ('k3',)
# 05. pstnp                               -> ('pstnp',)
# 06. onehot+k1                           -> ('onehot', 'k1')
# 07. onehot+k1+k2                        -> ('onehot', 'k1', 'k2')
# 08. onehot+k1+pstnp                     -> ('onehot', 'k1', 'pstnp')
# 09. onehot+pstnp                        -> ('onehot', 'pstnp')
# 10. onehot+k1+k2+k3                     -> ('onehot', 'k1', 'k2', 'k3')
# 11. onehot+k1+k2+pstnp                  -> ('onehot', 'k1', 'k2', 'pstnp')
# 12. k1+k2+k3+pstnp                      -> ('k1', 'k2', 'k3', 'pstnp')
# 13. k1+k2+pstnp                         -> ('k1', 'k2', 'pstnp')
# 14. k1+k2+k3                            -> ('k1', 'k2', 'k3')
#
# ====================================================================================================
# Running 1/14: onehot
# ====================================================================================================
# Selected features: ('onehot',); vector_dim=0
# Epoch 1: Loss: 0.5897 | Acc: 0.6920
# Epoch 2: Loss: 0.5203 | Acc: 0.7319
# Epoch 3: Loss: 0.5024 | Acc: 0.7518
# Epoch 4: Loss: 0.4974 | Acc: 0.7572
# Epoch 5: Acc: 0.7645
# Epoch 6: Loss: 0.4916 | Acc: 0.7708
# Epoch 7: Loss: 0.4819 | Acc: 0.7772
# Epoch 8: Loss: 0.4765 | Acc: 0.7781
# Epoch 9: Loss: 0.4637 | Acc: 0.7935
# Epoch 10: Loss: 0.4577 | Acc: 0.7962
# Epoch 11: Loss: 0.4550
# Epoch 13: Loss: 0.4468 | Acc: 0.7980
# Epoch 14: Loss: 0.4381 | Acc: 0.8025
# Epoch 15: Loss: 0.4358 | Acc: 0.8062
# Epoch 16: Loss: 0.4297
# Epoch 17: Acc: 0.8107
# Epoch 19: Loss: 0.4224
# Epoch 21: Loss: 0.4181 | Acc: 0.8234
# Epoch 23: Loss: 0.4170
# Epoch 26: Loss: 0.4152
# Epoch 28: Loss: 0.4123 | Acc: 0.8288
# Epoch 38: Loss: 0.4084
# Epoch 43: Acc: 0.8297
# Epoch 46: Loss: 0.4051
# Epoch 48: Loss: 0.4047
# Epoch 52: Acc: 0.8315
# Epoch 65: Acc: 0.8342
# Epoch 80: Loss: 0.4026 | Acc: 0.8370
# Epoch 82: Loss: 0.4015 | Acc: 0.8379
# Epoch 83: Loss: 0.4005
# Epoch 85: Loss: 0.3958
# Completed: onehot
# {'Experiment': 'onehot', 'Features': 'onehot', 'ACC': np.float64(0.8378623188405797), 'SN': np.float64(0.8695652173913043), 'SP': np.float64(0.8061594202898551), 'MCC': np.float64(0.6770870532717175), 'ROC_AUC': np.float64(0.9010416666666667), 'PR_AUC': np.float64(0.8708845612408214)}
#
# ====================================================================================================
# Running 2/14: k1
# ====================================================================================================
# Selected features: ('k1',); vector_dim=4
# Epoch 1: Loss: 0.6933 | Acc: 0.5199
# Epoch 2: Loss: 0.6895 | Acc: 0.5924
# Epoch 3: Loss: 0.6871 | Acc: 0.6440
# Epoch 4: Loss: 0.6853 | Acc: 0.7156
# Epoch 5: Loss: 0.6833 | Acc: 0.7201
# Epoch 102: Loss: 0.5235
# Epoch 103: Loss: 0.5231
# Epoch 105: Loss: 0.5219
# Epoch 107: Acc: 0.7591
# Epoch 109: Loss: 0.5217
# Epoch 110: Loss: 0.5206
# Epoch 115: Loss: 0.5205
# Epoch 116: Loss: 0.5199
# Epoch 117: Loss: 0.5188
# Epoch 118: Loss: 0.5185
# Epoch 122: Loss: 0.5177
# Epoch 130: Loss: 0.5165
# Epoch 133: Loss: 0.5165
# Epoch 134: Loss: 0.5164 | Acc: 0.7600
# Epoch 145: Loss: 0.5150
# Epoch 155: Loss: 0.5150
# Epoch 159: Loss: 0.5144
# Epoch 161: Loss: 0.5135
# Epoch 164: Loss: 0.5133
# Epoch 166: Loss: 0.5132
# Epoch 167: Loss: 0.5128
# Epoch 172: Loss: 0.5123
# Epoch 177: Loss: 0.5119
# Epoch 184: Loss: 0.5105
# Epoch 186: Loss: 0.5101
# Completed: k1
# {'Experiment': 'k1', 'Features': 'k1', 'ACC': np.float64(0.759963768115942), 'SN': np.float64(0.8079710144927537), 'SP': np.float64(0.7119565217391305), 'MCC': np.float64(0.5223407840341052), 'ROC_AUC': np.float64(0.8434349401386263), 'PR_AUC': np.float64(0.8356668350340865)}
#
# ====================================================================================================
# Running 3/14: k2
# ====================================================================================================
# Selected features: ('k2',); vector_dim=16
# Epoch 1: Loss: 0.6865 | Acc: 0.5996
# Epoch 2: Loss: 0.6775 | Acc: 0.6830
# Epoch 3: Loss: 0.6687 | Acc: 0.7074
# Epoch 4: Loss: 0.6579 | Acc: 0.7228
# Epoch 5: Loss: 0.6448 | Acc: 0.7355
# Epoch 6: Loss: 0.6325
# Epoch 7: Loss: 0.6207
# Epoch 8: Loss: 0.6091 | Acc: 0.7373
# Epoch 9: Loss: 0.5962
# Epoch 10: Loss: 0.5867
# Epoch 11: Loss: 0.5787 | Acc: 0.7382
# Epoch 12: Loss: 0.5710
# Epoch 13: Loss: 0.5666
# Epoch 14: Loss: 0.5617 | Acc: 0.7391
# Epoch 15: Loss: 0.5585 | Acc: 0.7428
# Epoch 16: Loss: 0.5547 | Acc: 0.7464
# Epoch 17: Loss: 0.5490
# Epoch 18: Loss: 0.5457
# Epoch 19: Loss: 0.5440
# Epoch 20: Loss: 0.5434
# Epoch 21: Loss: 0.5406
# Epoch 22: Loss: 0.5395 | Acc: 0.7482
# Epoch 23: Loss: 0.5375 | Acc: 0.7491
# Epoch 24: Loss: 0.5354
# Epoch 25: Loss: 0.5344
# Epoch 26: Loss: 0.5335
# Epoch 27: Loss: 0.5309
# Epoch 28: Loss: 0.5282
# Epoch 29: Loss: 0.5281
# Epoch 32: Loss: 0.5281
# Epoch 33: Loss: 0.5269
# Epoch 34: Loss: 0.5254 | Acc: 0.7509
# Epoch 35: Loss: 0.5250 | Acc: 0.7527
# Epoch 36: Loss: 0.5229
# Epoch 37: Loss: 0.5220
# Epoch 40: Loss: 0.5220
# Epoch 41: Loss: 0.5207
# Epoch 42: Loss: 0.5195 | Acc: 0.7536
# Epoch 21: Loss: 0.5080 | Acc: 0.7609
# Epoch 22: Loss: 0.5077
# Epoch 23: Loss: 0.5060
# Epoch 24: Loss: 0.5052 | Acc: 0.7627
# Epoch 25: Loss: 0.5046
# Epoch 26: Loss: 0.5035
# Epoch 27: Loss: 0.5019
# Epoch 28: Loss: 0.5016 | Acc: 0.7636
# Epoch 29: Loss: 0.5006 | Acc: 0.7645
# Epoch 30: Loss: 0.4990
# Epoch 31: Loss: 0.4986 | Acc: 0.7672
# Epoch 32: Loss: 0.4980
# Epoch 33: Loss: 0.4979 | Acc: 0.7690
# Epoch 34: Loss: 0.4973
# Epoch 35: Loss: 0.4967
# Epoch 36: Loss: 0.4953
# Epoch 37: Acc: 0.7717
# Epoch 41: Loss: 0.4946
# Epoch 43: Loss: 0.4939
# Epoch 44: Loss: 0.4930
# Epoch 45: Loss: 0.4929
# Epoch 47: Loss: 0.4923 | Acc: 0.7726
# Epoch 48: Acc: 0.7736
# Epoch 51: Loss: 0.4920
# Epoch 52: Loss: 0.4916 | Acc: 0.7745
# Epoch 53: Loss: 0.4909 | Acc: 0.7754
# Epoch 54: Loss: 0.4907
# Epoch 55: Loss: 0.4905
# Epoch 56: Acc: 0.7772
# Epoch 57: Loss: 0.4904
# Epoch 58: Loss: 0.4901
# Epoch 59: Loss: 0.4898
# Epoch 60: Loss: 0.4891
# Epoch 66: Loss: 0.4889
# Epoch 67: Loss: 0.4877
# Epoch 76: Loss: 0.4875
# Epoch 77: Loss: 0.4874
# Epoch 79: Loss: 0.4867
# Epoch 80: Loss: 0.4861
# Epoch 86: Loss: 0.4859
# Epoch 87: Loss: 0.4854
# Epoch 88: Loss: 0.4853
# Epoch 90: Loss: 0.4853
# Epoch 93: Loss: 0.4848
# Epoch 94: Loss: 0.4847
# Epoch 95: Loss: 0.4846
# Epoch 100: Loss: 0.4845
# Epoch 109: Loss: 0.4843
# Epoch 110: Loss: 0.4837
# Epoch 114: Loss: 0.4834
# Epoch 120: Loss: 0.4831
# Epoch 125: Loss: 0.4827
# Epoch 129: Loss: 0.4826
# Epoch 134: Loss: 0.4824
# Completed: k3
# {'Experiment': 'k3', 'Features': 'k3', 'ACC': np.float64(0.7771739130434783), 'SN': np.float64(0.802536231884058), 'SP': np.float64(0.7518115942028986), 'MCC': np.float64(0.5550623706621496), 'ROC_AUC': np.float64(0.8477374763705104), 'PR_AUC': np.float64(0.8379257572160006)}
#
# ====================================================================================================
# Running 5/14: pstnp
# ====================================================================================================
# Selected features: ('pstnp',); vector_dim=199
# Epoch 1: Loss: 0.6763 | Acc: 0.5697
# Epoch 2: Loss: 0.6402 | Acc: 0.7011
# Epoch 3: Loss: 0.6038 | Acc: 0.7038
# Epoch 4: Loss: 0.5808
# Epoch 5: Loss: 0.5678 | Acc: 0.7065
# Epoch 6: Loss: 0.5619
# Epoch 7: Loss: 0.5584
# Epoch 8: Loss: 0.5575
# Epoch 9: Loss: 0.5559
# Epoch 10: Loss: 0.5548
# Epoch 11: Loss: 0.5539
# Epoch 12: Loss: 0.5532 | Acc: 0.7074
# Epoch 13: Loss: 0.5529 | Acc: 0.7083
# Epoch 14: Loss: 0.5527
# Epoch 15: Loss: 0.5522
# Epoch 16: Acc: 0.7101
# Epoch 17: Loss: 0.5518
# Epoch 18: Loss: 0.5511 | Acc: 0.7120
# Epoch 22: Loss: 0.5510
# Epoch 25: Loss: 0.5510 | Acc: 0.7129
# Epoch 26: Loss: 0.5509
# Epoch 27: Loss: 0.5506
# Epoch 28: Loss: 0.5504
# Epoch 30: Loss: 0.5503
# Epoch 31: Loss: 0.5503
# Epoch 54: Loss: 0.5503
# Epoch 55: Loss: 0.5500
# Epoch 62: Loss: 0.5500
# Epoch 85: Loss: 0.5499
# Epoch 87: Loss: 0.5499
# Epoch 88: Loss: 0.5498
# Completed: pstnp
# {'Experiment': 'pstnp', 'Features': 'pstnp', 'ACC': np.float64(0.7128623188405797), 'SN': np.float64(0.6902173913043478), 'SP': np.float64(0.7355072463768116), 'MCC': np.float64(0.4261619275229798), 'ROC_AUC': np.float64(0.7932879122033185), 'PR_AUC': np.float64(0.762046451346553)}
#
# ====================================================================================================
# Running 6/14: onehot+k1
# ====================================================================================================
# Selected features: ('onehot', 'k1'); vector_dim=4
# Epoch 1: Loss: 0.5346 | Acc: 0.7246
# Epoch 2: Acc: 0.7301
# Epoch 3: Loss: 0.5064 | Acc: 0.7491
# Epoch 4: Loss: 0.4872 | Acc: 0.7717
# Epoch 5: Loss: 0.4827
# Epoch 6: Loss: 0.4823
# Epoch 7: Loss: 0.4689 | Acc: 0.7962
# Epoch 8: Loss: 0.4638 | Acc: 0.8043
# Epoch 9: Loss: 0.4601
# Epoch 10: Loss: 0.4481 | Acc: 0.8053
# Epoch 11: Acc: 0.8062
# Epoch 12: Loss: 0.4460
# Epoch 13: Loss: 0.4246 | Acc: 0.8107
# Epoch 16: Loss: 0.4128 | Acc: 0.8216
# Epoch 21: Acc: 0.8297
# Epoch 39: Loss: 0.4110
# Epoch 62: Loss: 0.4052 | Acc: 0.8315
# Epoch 68: Acc: 0.8333
# Epoch 72: Loss: 0.4045
# Epoch 74: Loss: 0.4022
# Epoch 79: Loss: 0.4017 | Acc: 0.8342
# Epoch 80: Acc: 0.8351
# Epoch 85: Loss: 0.3988 | Acc: 0.8370
# Epoch 104: Loss: 0.3988
# Epoch 127: Acc: 0.8388
# Completed: onehot+k1
# {'Experiment': 'onehot+k1', 'Features': 'onehot+k1', 'ACC': np.float64(0.8387681159420289), 'SN': np.float64(0.8514492753623188), 'SP': np.float64(0.8260869565217391), 'MCC': np.float64(0.6777542487165166), 'ROC_AUC': np.float64(0.906663516068053), 'PR_AUC': np.float64(0.8859324774496036)}
#
# ====================================================================================================
# Running 7/14: onehot+k1+k2
# ====================================================================================================
# Selected features: ('onehot', 'k1', 'k2'); vector_dim=20
# Epoch 1: Loss: 0.6154 | Acc: 0.6676
# Epoch 2: Loss: 0.5418 | Acc: 0.7255
# Epoch 3: Loss: 0.5364
# Epoch 4: Loss: 0.5287 | Acc: 0.7437
# Epoch 6: Loss: 0.5180 | Acc: 0.7464
# Epoch 7: Loss: 0.5123 | Acc: 0.7527
# Epoch 8: Loss: 0.5096 | Acc: 0.7545
# Epoch 9: Loss: 0.5013
# Epoch 10: Loss: 0.4903 | Acc: 0.7636
# Epoch 11: Loss: 0.4849 | Acc: 0.7645
# Epoch 12: Loss: 0.4811
# Epoch 13: Loss: 0.4722 | Acc: 0.7745
# Epoch 14: Loss: 0.4681 | Acc: 0.7754
# Epoch 16: Loss: 0.4653 | Acc: 0.7799
# Epoch 17: Loss: 0.4522
# Epoch 18: Loss: 0.4483 | Acc: 0.7844
# Epoch 19: Loss: 0.4436 | Acc: 0.7880
# Epoch 20: Acc: 0.7899
# Epoch 22: Loss: 0.4381 | Acc: 0.7917
# Epoch 23: Loss: 0.4363 | Acc: 0.8025
# Epoch 24: Loss: 0.4257
# Epoch 27: Loss: 0.4228 | Acc: 0.8043
# Epoch 28: Acc: 0.8080
# Epoch 29: Loss: 0.4220
# Epoch 30: Loss: 0.4157 | Acc: 0.8125
# Epoch 37: Loss: 0.4124 | Acc: 0.8143
# Epoch 38: Loss: 0.4104 | Acc: 0.8170
# Epoch 39: Loss: 0.4036 | Acc: 0.8243
# Epoch 47: Loss: 0.4016 | Acc: 0.8261
# Epoch 55: Loss: 0.4011
# Epoch 56: Loss: 0.4005
# Epoch 57: Loss: 0.3962 | Acc: 0.8306
# Epoch 63: Acc: 0.8324
# Epoch 65: Acc: 0.8333
# Epoch 66: Loss: 0.3941
# Epoch 68: Loss: 0.3931
# Epoch 80: Acc: 0.8361
# Epoch 87: Acc: 0.8370
# Epoch 96: Acc: 0.8406
# Completed: onehot+k1+k2
# {'Experiment': 'onehot+k1+k2', 'Features': 'onehot+k1+k2', 'ACC': np.float64(0.8405797101449275), 'SN': np.float64(0.8695652173913043), 'SP': np.float64(0.8115942028985508), 'MCC': np.float64(0.682306878538961), 'ROC_AUC': np.float64(0.9036146555345516), 'PR_AUC': np.float64(0.8780629944203274)}
#
# ====================================================================================================
# Running 8/14: onehot+k1+pstnp
# ====================================================================================================
# Selected features: ('onehot', 'k1', 'pstnp'); vector_dim=203
# Epoch 1: Loss: 0.5015 | Acc: 0.7717
# Epoch 2: Loss: 0.4773 | Acc: 0.7899
# Epoch 3: Loss: 0.4650 | Acc: 0.7980
# Epoch 4: Loss: 0.4573 | Acc: 0.8034
# Epoch 5: Loss: 0.4544 | Acc: 0.8053
# Epoch 7: Loss: 0.4522 | Acc: 0.8062
# Epoch 10: Loss: 0.4510
# Epoch 11: Loss: 0.4453
# Epoch 13: Loss: 0.4411 | Acc: 0.8143
# Epoch 15: Loss: 0.4349
# Epoch 16: Loss: 0.4306 | Acc: 0.8170
# Epoch 19: Loss: 0.4262
# Epoch 20: Loss: 0.4259
# Epoch 24: Loss: 0.4200
# Epoch 25: Loss: 0.4193 | Acc: 0.8179
# Epoch 26: Loss: 0.4184
# Epoch 30: Loss: 0.4165
# Epoch 31: Loss: 0.4139 | Acc: 0.8216
# Epoch 39: Loss: 0.4136
# Epoch 42: Loss: 0.4107
# Epoch 62: Acc: 0.8234
# Epoch 64: Acc: 0.8270
# Epoch 69: Acc: 0.8279
# Epoch 71: Acc: 0.8324
# Epoch 105: Acc: 0.8342
# Epoch 111: Loss: 0.4099
# Epoch 118: Loss: 0.4024
# Completed: onehot+k1+pstnp
# {'Experiment': 'onehot+k1+pstnp', 'Features': 'onehot+k1+pstnp', 'ACC': np.float64(0.8342391304347826), 'SN': np.float64(0.8605072463768116), 'SP': np.float64(0.8079710144927537), 'MCC': np.float64(0.6694026935284509), 'ROC_AUC': np.float64(0.8963256143667296), 'PR_AUC': np.float64(0.8710314992738047)}
#
# ====================================================================================================
# Running 9/14: onehot+pstnp
# ====================================================================================================
# Selected features: ('onehot', 'pstnp'); vector_dim=199
# Epoch 1: Loss: 0.5626 | Acc: 0.7111
# Epoch 2: Loss: 0.5261 | Acc: 0.7482
# Epoch 3: Loss: 0.4949 | Acc: 0.7745
# Epoch 4: Loss: 0.4630 | Acc: 0.7908
# Epoch 5: Loss: 0.4538 | Acc: 0.7998
# Epoch 7: Loss: 0.4480
# Epoch 9: Loss: 0.4422 | Acc: 0.8007
# Epoch 12: Loss: 0.4303 | Acc: 0.8062
# Epoch 15: Loss: 0.4253
# Epoch 17: Loss: 0.4157
# Epoch 20: Loss: 0.4150 | Acc: 0.8089
# Completed: onehot+pstnp
# {'Experiment': 'onehot+pstnp', 'Features': 'onehot+pstnp', 'ACC': np.float64(0.8088768115942029), 'SN': np.float64(0.7916666666666666), 'SP': np.float64(0.8260869565217391), 'MCC': np.float64(0.6181198924404736), 'ROC_AUC': np.float64(0.8937099611426172), 'PR_AUC': np.float64(0.8728373735476505)}
#
# ====================================================================================================
# Running 10/14: onehot+k1+k2+k3
# ====================================================================================================
# Selected features: ('onehot', 'k1', 'k2', 'k3'); vector_dim=84
# Epoch 1: Loss: 0.5538 | Acc: 0.7111
# Epoch 2: Loss: 0.5144 | Acc: 0.7609
# Epoch 3: Loss: 0.4942 | Acc: 0.7736
# Epoch 4: Loss: 0.4739 | Acc: 0.7808
# Epoch 5: Loss: 0.4689 | Acc: 0.7899
# Epoch 6: Loss: 0.4604 | Acc: 0.7971
# Epoch 7: Loss: 0.4543 | Acc: 0.7998
# Epoch 8: Acc: 0.8062
# Epoch 10: Loss: 0.4420 | Acc: 0.8107
# Epoch 11: Loss: 0.4413
# Epoch 12: Loss: 0.4377
# Epoch 13: Loss: 0.4332
# Epoch 15: Loss: 0.4171
# Epoch 18: Loss: 0.4145 | Acc: 0.8152
# Epoch 19: Loss: 0.4119
# Epoch 23: Loss: 0.4113
# Epoch 27: Loss: 0.4073 | Acc: 0.8188
# Epoch 35: Acc: 0.8207
# Epoch 36: Acc: 0.8216
# Epoch 38: Acc: 0.8243
# Epoch 39: Loss: 0.4067 | Acc: 0.8288
# Epoch 40: Loss: 0.4057
# Epoch 42: Acc: 0.8297
# Epoch 43: Loss: 0.4037
# Epoch 45: Loss: 0.4028 | Acc: 0.8306
# Epoch 50: Loss: 0.4008 | Acc: 0.8315
# Epoch 124: Loss: 0.3949
# Epoch 131: Acc: 0.8324
# Epoch 132: Acc: 0.8342
# Epoch 136: Acc: 0.8370
# Completed: onehot+k1+k2+k3
# {'Experiment': 'onehot+k1+k2+k3', 'Features': 'onehot+k1+k2+k3', 'ACC': np.float64(0.8369565217391305), 'SN': np.float64(0.8097826086956522), 'SP': np.float64(0.8641304347826086), 'MCC': np.float64(0.6749105175203279), 'ROC_AUC': np.float64(0.9070835958832177), 'PR_AUC': np.float64(0.8872419829722517)}
#
# ====================================================================================================
# Running 11/14: onehot+k1+k2+pstnp
# ====================================================================================================
# Selected features: ('onehot', 'k1', 'k2', 'pstnp'); vector_dim=219
# Epoch 1: Loss: 0.5787 | Acc: 0.7283
# Epoch 2: Loss: 0.5393 | Acc: 0.7572
# Epoch 3: Loss: 0.5356
# Epoch 4: Loss: 0.4966 | Acc: 0.7763
# Epoch 5: Loss: 0.4789 | Acc: 0.7908
# Epoch 8: Loss: 0.4724
# Epoch 9: Loss: 0.4705
# Epoch 10: Loss: 0.4623
# Epoch 12: Loss: 0.4576 | Acc: 0.7935
# Epoch 13: Loss: 0.4425
# Epoch 15: Loss: 0.4371 | Acc: 0.8007
# Epoch 17: Loss: 0.4270 | Acc: 0.8080
# Epoch 19: Loss: 0.4253
# Epoch 21: Loss: 0.4243
# Epoch 24: Loss: 0.4188 | Acc: 0.8116
# Epoch 26: Acc: 0.8161
# Epoch 29: Loss: 0.4157
# Epoch 31: Loss: 0.4117
# Epoch 32: Loss: 0.4109 | Acc: 0.8207
# Epoch 35: Loss: 0.4067 | Acc: 0.8252
# Epoch 39: Loss: 0.4052
# Epoch 40: Loss: 0.4029 | Acc: 0.8270
# Epoch 41: Loss: 0.4025
# Epoch 47: Acc: 0.8297
# Epoch 50: Loss: 0.3998
# Epoch 53: Acc: 0.8361
# Epoch 75: Loss: 0.3973 | Acc: 0.8379
# Epoch 100: Acc: 0.8388
# Epoch 102: Loss: 0.3931
# Epoch 103: Loss: 0.3915 | Acc: 0.8397
# Epoch 104: Loss: 0.3911 | Acc: 0.8406
# Epoch 106: Loss: 0.3901 | Acc: 0.8451
# Epoch 107: Loss: 0.3894
# Completed: onehot+k1+k2+pstnp
# {'Experiment': 'onehot+k1+k2+pstnp', 'Features': 'onehot+k1+k2+pstnp', 'ACC': np.float64(0.845108695652174), 'SN': np.float64(0.8514492753623188), 'SP': np.float64(0.8387681159420289), 'MCC': np.float64(0.6902728955507488), 'ROC_AUC': np.float64(0.9065027042638101), 'PR_AUC': np.float64(0.8798611099892117)}
#
# ====================================================================================================
# Running 12/14: k1+k2+k3+pstnp
# ====================================================================================================
# Selected features: ('k1', 'k2', 'k3', 'pstnp'); vector_dim=283
# Epoch 1: Loss: 0.6324 | Acc: 0.7020
# Epoch 2: Loss: 0.5706 | Acc: 0.7120
# Epoch 107: Loss: 0.4709
# Epoch 108: Loss: 0.4707
# Epoch 109: Loss: 0.4705
# Epoch 111: Loss: 0.4704
# Epoch 112: Loss: 0.4702
# Epoch 114: Loss: 0.4699
# Epoch 116: Loss: 0.4697
# Epoch 117: Loss: 0.4695
# Epoch 134: Loss: 0.4694
# Epoch 135: Loss: 0.4693
# Epoch 136: Loss: 0.4688
# Epoch 137: Loss: 0.4683
# Epoch 138: Loss: 0.4683
# Epoch 153: Loss: 0.4683
# Epoch 156: Loss: 0.4673
# Epoch 177: Loss: 0.4671
# Epoch 197: Loss: 0.4670
# Epoch 200: Loss: 0.4667
# Completed: k1+k2+k3+pstnp
# {'Experiment': 'k1+k2+k3+pstnp', 'Features': 'k1+k2+k3+pstnp', 'ACC': np.float64(0.7853260869565217), 'SN': np.float64(0.8206521739130435), 'SP': np.float64(0.75), 'MCC': np.float64(0.5720817990681111), 'ROC_AUC': np.float64(0.8572385003150599), 'PR_AUC': np.float64(0.845144783189131)}
#
# ====================================================================================================
# Running 13/14: k1+k2+pstnp
# ====================================================================================================
# Selected features: ('k1', 'k2', 'pstnp'); vector_dim=219
# Epoch 1: Loss: 0.6821 | Acc: 0.6504
# Epoch 2: Loss: 0.6609 | Acc: 0.6857
# Epoch 3: Loss: 0.6374 | Acc: 0.7011
# Epoch 4: Loss: 0.6120 | Acc: 0.7074
# Epoch 5: Loss: 0.5908 | Acc: 0.7120
# Epoch 6: Loss: 0.5753 | Acc: 0.7156
# Epoch 7: Loss: 0.5637 | Acc: 0.7219
# Epoch 8: Loss: 0.5548 | Acc: 0.7246
# Epoch 9: Loss: 0.5481 | Acc: 0.7283
# Epoch 10: Loss: 0.5432 | Acc: 0.7337
# Epoch 11: Loss: 0.5389 | Acc: 0.7355
# Epoch 12: Loss: 0.5363
# Epoch 13: Loss: 0.5325 | Acc: 0.7391
# Epoch 14: Loss: 0.5299
# Epoch 15: Loss: 0.5277
# Epoch 16: Loss: 0.5253 | Acc: 0.7473
# Epoch 17: Loss: 0.5246
# Epoch 18: Loss: 0.5219 | Acc: 0.7491
# Epoch 19: Loss: 0.5199 | Acc: 0.7500
# Epoch 20: Loss: 0.5186
# Epoch 21: Loss: 0.5167 | Acc: 0.7527
# Epoch 22: Loss: 0.5161
# Epoch 23: Loss: 0.5146
# Epoch 24: Loss: 0.5145
# Epoch 25: Loss: 0.5131 | Acc: 0.7545
# Epoch 26: Loss: 0.5119
# Epoch 27: Loss: 0.5101
# Epoch 28: Loss: 0.5088 | Acc: 0.7554
# Epoch 29: Loss: 0.5078 | Acc: 0.7563
# Epoch 30: Loss: 0.5070
# Epoch 31: Loss: 0.5050 | Acc: 0.7572
# Epoch 32: Acc: 0.7591
# Epoch 33: Loss: 0.5040
# Epoch 34: Loss: 0.5037 | Acc: 0.7600
# Epoch 35: Loss: 0.5025
# Epoch 36: Loss: 0.5024
# Epoch 37: Loss: 0.5005 | Acc: 0.7609
# Epoch 38: Loss: 0.5003 | Acc: 0.7618
# Epoch 95: Loss: 0.4755
# Epoch 96: Loss: 0.4754
# Epoch 97: Loss: 0.4753
# Epoch 98: Loss: 0.4752
# Epoch 101: Loss: 0.4751
# Epoch 102: Acc: 0.7835
# Epoch 103: Loss: 0.4745
# Epoch 108: Acc: 0.7844
# Epoch 111: Loss: 0.4743
# Epoch 113: Loss: 0.4740
# Epoch 114: Loss: 0.4739
# Epoch 115: Loss: 0.4739
# Epoch 117: Loss: 0.4735
# Epoch 123: Loss: 0.4730
# Epoch 124: Loss: 0.4729
# Epoch 128: Loss: 0.4727
# Epoch 129: Acc: 0.7853
# Epoch 130: Loss: 0.4727
# Epoch 131: Acc: 0.7862
# Epoch 132: Loss: 0.4725
# Epoch 133: Loss: 0.4716
# Epoch 134: Loss: 0.4711
# Epoch 146: Acc: 0.7889
# Epoch 152: Loss: 0.4706
# Epoch 158: Loss: 0.4705
# Epoch 163: Acc: 0.7899
# Epoch 164: Acc: 0.7908
# Epoch 169: Loss: 0.4699
# Epoch 178: Acc: 0.7917
# Epoch 179: Acc: 0.7926
# Epoch 185: Loss: 0.4696
# Completed: k1+k2+k3
# {'Experiment': 'k1+k2+k3', 'Features': 'k1+k2+k3', 'ACC': np.float64(0.792572463768116), 'SN': np.float64(0.8134057971014492), 'SP': np.float64(0.7717391304347826), 'MCC': np.float64(0.5856535281776969), 'ROC_AUC': np.float64(0.8603431526990128), 'PR_AUC': np.float64(0.8496443465998647)}
#
# Final Ablation Results Table:
#             Experiment            Features     ACC      SN      SP     MCC  ROC_AUC  PR_AUC
# 0      onehot+k1+k2+k3     onehot+k1+k2+k3  0.8370  0.8098  0.8641  0.6749   0.9071  0.8872
# 1            onehot+k1           onehot+k1  0.8388  0.8514  0.8261  0.6778   0.9067  0.8859
# 2   onehot+k1+k2+pstnp  onehot+k1+k2+pstnp  0.8451  0.8514  0.8388  0.6903   0.9065  0.8799
# 3         onehot+k1+k2        onehot+k1+k2  0.8406  0.8696  0.8116  0.6823   0.9036  0.8781
# 4               onehot              onehot  0.8379  0.8696  0.8062  0.6771   0.9010  0.8709
# 5      onehot+k1+pstnp     onehot+k1+pstnp  0.8342  0.8605  0.8080  0.6694   0.8963  0.8710
# 6         onehot+pstnp        onehot+pstnp  0.8089  0.7917  0.8261  0.6181   0.8937  0.8728
# 7             k1+k2+k3            k1+k2+k3  0.7926  0.8134  0.7717  0.5857   0.8603  0.8496
# 8          k1+k2+pstnp         k1+k2+pstnp  0.7889  0.8207  0.7572  0.5791   0.8583  0.8451
# 9       k1+k2+k3+pstnp      k1+k2+k3+pstnp  0.7853  0.8207  0.7500  0.5721   0.8572  0.8451
# 10                  k2                  k2  0.7726  0.7899  0.7554  0.5456   0.8485  0.8324
# 11                  k3                  k3  0.7772  0.8025  0.7518  0.5551   0.8477  0.8379
# 12                  k1                  k1  0.7600  0.8080  0.7120  0.5223   0.8434  0.8357
# 13               pstnp               pstnp  0.7129  0.6902  0.7355  0.4262   0.7933  0.7620
# Saved file: ablation_independent_results.csv
